# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Times", "Times New Roman", "DejaVu Serif"],
    "font.size": 10,
    "axes.labelsize": 10,
    "axes.titlesize": 10,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "legend.fontsize": 9,
    "axes.edgecolor": "black",
    "axes.linewidth": 0.8,
    "savefig.dpi": 400
})

depths = np.array([1, 2, 3, 4, 5])
direct = [50, 60, 80, 90, 80]
reasoning = [20, 20, 10, 0, 0]

plt.figure(figsize=(3.3, 2.2))
plt.bar(depths - 0.15, direct, width=0.3, color="#4879c7", label="Direct")
plt.bar(depths + 0.15, reasoning, width=0.3, color="#e69d73", label="Reasoning")
plt.xlabel("Depth")
plt.ylabel("Accuracy (%)")
plt.title("Accuracy vs Depth — GPT-5 on ProofWriter")
plt.legend(frameon=False)
plt.tight_layout()
plt.savefig("acc_gpt5_proofwriter.pdf", bbox_inches="tight")
plt.close()

# %%
import matplotlib.pyplot as plt
import numpy as np

depths = np.array([1, 2, 3, 4, 5])
delta_reason = [-25, -40, -70, -90, -80]



plt.figure(figsize=(3.3, 2.2))
plt.bar(depths, delta_reason, color="#4879c7", edgecolor="black", alpha=0.7)
plt.xlabel("Depth")
plt.ylabel("ΔReasoning (pp)")
plt.title("ΔReasoning vs Depth — GPT-5 on ProofWriter")
plt.tight_layout()
plt.savefig("delta_gpt5_proofwriter.pdf", bbox_inches="tight")
plt.close()

# %%
import matplotlib.pyplot as plt
import numpy as np

depths = np.array([2, 3, 4, 5, 6])
direct = [20, 20, 20, 20, 20]
reasoning = [30, 20, 20, 20, 20]

plt.figure(figsize=(3.3, 2.2))
plt.bar(depths - 0.15, direct, width=0.3, color="#4879c7", label="Direct")
plt.bar(depths + 0.15, reasoning, width=0.3, color="#e69d73", label="Reasoning")
plt.xlabel("Depth")
plt.ylabel("Accuracy (%)")
plt.title("Accuracy vs Depth — Llama31_8B on CLUTRR")
plt.legend(frameon=False)
plt.tight_layout()
plt.savefig("acc_llama31_8b_clutrr.pdf", bbox_inches="tight")
plt.close()

# %%
import matplotlib.pyplot as plt
import numpy as np

depths = np.array([2, 3, 4, 5, 6])
direct = [10, 0, 0, 30, 0]
reasoning = [10, 0, 20, 0, 0]

plt.figure(figsize=(3.3, 2.2))
plt.bar(depths - 0.15, direct, width=0.3, color="#4c72b0", label="Direct")
plt.bar(depths + 0.15, reasoning, width=0.3, color="#dd8452", label="Reasoning")
plt.xlabel("Depth")
plt.ylabel("Accuracy (%)")
plt.title("Accuracy vs Depth — qwen25_7b on clutrr")
plt.legend(frameon=False)
plt.tight_layout()
plt.savefig("acc_qwen25_7b_clutrr.pdf", bbox_inches="tight")
plt.close()

# %%
import matplotlib.pyplot as plt
import numpy as np

# ============================================================
#  GLOBAL AAAI-SAFE STYLE CONFIGURATION
# ============================================================
plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Times", "Nimbus Roman", "Times New Roman", "DejaVu Serif"],
    "font.size": 10,
    "axes.labelsize": 10,
    "axes.titlesize": 10,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "legend.fontsize": 9,
    "axes.edgecolor": "black",
    "axes.linewidth": 0.8,
    "savefig.dpi": 400
})

# ============================================================
#  EXAMPLE SAMPLE DATA  (replace these with your actual results)
# ============================================================
depths = np.array([1, 2, 3, 4, 5])
gpt5_direct = [50, 60, 80, 90, 80]
gpt5_reason = [20, 20, 10, 0, 10]
delta_reason = [-15, -40, -70, -90, -80]
llama_direct = [20, 40, 50, 55, 60]
llama_reason = [30, 45, 55, 60, 65]
qwen_direct = [10, 20, 25, 30, 35]
qwen_reason = [15, 25, 30, 35, 40]

# ============================================================
# 1. GPT-5 Accuracy (ProofWriter)
# ============================================================
plt.figure(figsize=(3.3, 2.2))
plt.bar(depths - 0.15, gpt5_direct, width=0.3, label="Direct", color="#4c72b0")
plt.bar(depths + 0.15, gpt5_reason, width=0.3, label="Reasoning", color="#dd8452")
plt.xlabel("Depth")
plt.ylabel("Accuracy (%)")
plt.title("Accuracy vs Depth — GPT-5 on ProofWriter")
plt.legend(frameon=False)
plt.tight_layout()
plt.savefig("acc_gpt5_proofwriter_b.pdf")   # vector output
plt.close()

# ============================================================
# 2. GPT-5 ΔReasoning (ProofWriter)
# ============================================================
plt.figure(figsize=(3.3, 2.2))
plt.bar(depths, delta_reason, color="#4c72b0", edgecolor="black", alpha=0.7)
plt.xlabel("Depth")
plt.ylabel("ΔReasoning (pp)")
plt.title("ΔReasoning vs Depth — GPT-5 on ProofWriter")
plt.tight_layout()
plt.savefig("delta_gpt5_proofwriter_b.pdf")
plt.close()

# ============================================================
# 3. LLaMA-3.1-8B Accuracy (CLUTRR)
# ============================================================
plt.figure(figsize=(3.3, 2.2))
plt.bar(depths - 0.15, llama_direct, width=0.3, label="Direct", color="#4c72b0")
plt.bar(depths + 0.15, llama_reason, width=0.3, label="Reasoning", color="#dd8452")
plt.xlabel("Depth")
plt.ylabel("Accuracy (%)")
plt.title("Accuracy vs Depth — LLaMA-3.1-8B on CLUTRR")
plt.legend(frameon=False)
plt.tight_layout()
plt.savefig("acc_llama31_8b_clutrr_b.pdf")
plt.close()

# ============================================================
# 4. Qwen-2.5-7B Accuracy (CLUTRR)
# ============================================================
plt.figure(figsize=(3.3, 2.2))
plt.bar(depths - 0.15, qwen_direct, width=0.3, label="Direct", color="#4c72b0")
plt.bar(depths + 0.15, qwen_reason, width=0.3, label="Reasoning", color="#dd8452")
plt.xlabel("Depth")
plt.ylabel("Accuracy (%)")
plt.title("Accuracy vs Depth — Qwen-2.5-7B on CLUTRR")
plt.legend(frameon=False)
plt.tight_layout()
plt.savefig("acc_qwen25_7b_clutrr_b.pdf")
plt.close()

print("✅ AAAI-style figures saved as PDF with sharp fonts!")
# Out:
# ✅ AAAI-style figures saved as PDF with sharp fonts!

# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42    # Use TrueType fonts
matplotlib.rcParams['ps.fonttype'] = 42     # Ensures EPS compatibility
matplotlib.rcParams['svg.fonttype'] = 'none'  # Keeps text editable in SVG/PDF
import numpy as np

# --------------------------------------------------
# Global figure style (AAAI / ICML safe)
# --------------------------------------------------
plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Times", "Times New Roman", "DejaVu Serif"],
    "font.size": 9,
    "axes.labelsize": 9,
    "axes.titlesize": 9,
    "xtick.labelsize": 8,
    "ytick.labelsize": 8,
    "legend.fontsize": 8,
    "axes.edgecolor": "black",
    "axes.linewidth": 0.8,
})

# --------------------------------------------------
# Data definitions
# --------------------------------------------------
depths_gpt5 = np.array([1, 2, 3, 4, 5])
gpt5_direct = [50, 60, 80, 90, 80]
gpt5_reason = [20, 20, 10, 0, 0]
delta_reason = [-25, -40, -70, -90, -80]

depths_llama = np.array([2, 3, 4, 5, 6])
llama_direct = [20, 20, 20, 20, 20]
llama_reason = [30, 20, 20, 20, 20]

depths_qwen = np.array([2, 3, 4, 5, 6])
qwen_direct = [10, 0, 0, 30, 0]
qwen_reason = [10, 0, 20, 0, 0]

# --------------------------------------------------
# 2x2 Grid Layout
# --------------------------------------------------
fig, axs = plt.subplots(2, 2, figsize=(6.5, 4.5))  # balanced square layout
plt.subplots_adjust(wspace=0.35, hspace=0.35)

# --- Top Left: GPT-5 Accuracy ---
ax = axs[0, 0]
ax.bar(depths_gpt5 - 0.15, gpt5_direct, width=0.3, color="#4c72b0", label="Direct")
ax.bar(depths_gpt5 + 0.15, gpt5_reason, width=0.3, color="#dd8452", label="Reasoning")
ax.set_xlabel("Depth")
ax.set_ylabel("Accuracy (%)")
ax.set_title("Accuracy vs Depth — GPT-5 on ProofWriter")
ax.legend(frameon=False)

# --- Top Right: GPT-5 ΔReasoning ---
ax = axs[0, 1]
ax.bar(depths_gpt5, delta_reason, color="#4c72b0", edgecolor="black", alpha=0.7)
ax.set_xlabel("Depth")
ax.set_ylabel("ΔReasoning (pp)")
ax.set_title("ΔReasoning vs Depth — GPT-5 on ProofWriter")

# --- Bottom Left: LLaMA-3.1-8B ---
ax = axs[1, 0]
ax.bar(depths_llama - 0.15, llama_direct, width=0.3, color="#4c72b0", label="Direct")
ax.bar(depths_llama + 0.15, llama_reason, width=0.3, color="#dd8452", label="Reasoning")
ax.set_xlabel("Depth")
ax.set_ylabel("Accuracy (%)")
ax.set_title("Accuracy vs Depth — Llama31_8B on CLUTRR")
ax.legend(frameon=False)

# --- Bottom Right: Qwen-2.5-7B ---
ax = axs[1, 1]
ax.bar(depths_qwen - 0.15, qwen_direct, width=0.3, color="#4c72b0", label="Direct")
ax.bar(depths_qwen + 0.15, qwen_reason, width=0.3, color="#dd8452", label="Reasoning")
ax.set_xlabel("Depth")
ax.set_ylabel("Accuracy (%)")
ax.set_title("Accuracy vs Depth — Qwen25_7B on CLUTRR")
ax.legend(frameon=False)

# --------------------------------------------------
# Layout and Save
# --------------------------------------------------
fig.tight_layout()
fig.savefig("figure2_accuracy_reasoning_collapse.pdf", bbox_inches="tight", dpi=400)
plt.close()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# --- Make all fonts PDF/A safe ---
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
matplotlib.rcParams['svg.fonttype'] = 'none'
matplotlib.rcParams['font.family'] = 'DejaVu Serif'
# --- Ensure vector-safe output ---
matplotlib.rcParams.update({
    "pdf.fonttype": 42,            # embed TrueType
    "ps.fonttype": 42,
    "svg.fonttype": "none",
    "path.simplify": True,         # enable path simplification
    "path.simplify_threshold": 0.5,# higher value = fewer points
    "agg.path.chunksize": 2000,    # split long paths
    "font.family": "DejaVu Serif",
})
# --------------------------------------------------
plt.rcParams.update({
    "font.size": 9,
    "axes.labelsize": 9,
    "axes.titlesize": 9,
    "xtick.labelsize": 8,
    "ytick.labelsize": 8,
    "legend.fontsize": 8,
    "axes.edgecolor": "black",
    "axes.linewidth": 0.8,
})

# --------------------------------------------------
depths_gpt5 = np.array([1, 2, 3, 4, 5])
gpt5_direct = [50, 60, 80, 90, 80]
gpt5_reason = [20, 20, 10, 0, 0]
delta_reason = [-25, -40, -70, -90, -80]
depths_llama = np.array([2, 3, 4, 5, 6])
llama_direct = [20, 20, 20, 20, 20]
llama_reason = [30, 20, 20, 20, 20]
depths_qwen = np.array([2, 3, 4, 5, 6])
qwen_direct = [10, 0, 0, 30, 0]
qwen_reason = [10, 0, 20, 0, 0]

fig, axs = plt.subplots(2, 2, figsize=(6.5, 4.5))
plt.subplots_adjust(wspace=0.35, hspace=0.35)

# --- GPT-5 Accuracy ---
ax = axs[0, 0]
ax.bar(depths_gpt5 - 0.15, gpt5_direct, width=0.3, color="#4c72b0", label="Direct")
ax.bar(depths_gpt5 + 0.15, gpt5_reason, width=0.3, color="#dd8452", label="Reasoning")
ax.set_xlabel("Depth"); ax.set_ylabel("Accuracy (%)")
ax.set_title("Accuracy vs Depth — GPT-5 on ProofWriter"); ax.legend(frameon=False)

# --- GPT-5 ΔReasoning ---
ax = axs[0, 1]
ax.bar(depths_gpt5, delta_reason, color="#4c72b0", edgecolor="black")
ax.set_xlabel("Depth"); ax.set_ylabel("ΔReasoning (pp)")
ax.set_title("ΔReasoning vs Depth — GPT-5 on ProofWriter")

# --- LLaMA-3.1-8B ---
ax = axs[1, 0]
ax.bar(depths_llama - 0.15, llama_direct, width=0.3, color="#4c72b0", label="Direct")
ax.bar(depths_llama + 0.15, llama_reason, width=0.3, color="#dd8452", label="Reasoning")
ax.set_xlabel("Depth"); ax.set_ylabel("Accuracy (%)")
ax.set_title("Accuracy vs Depth — LLaMA-3.1-8B on CLUTRR"); ax.legend(frameon=False)

# --- Qwen-2.5-7B ---
ax = axs[1, 1]
ax.bar(depths_qwen - 0.15, qwen_direct, width=0.3, color="#4c72b0", label="Direct")
ax.bar(depths_qwen + 0.15, qwen_reason, width=0.3, color="#dd8452", label="Reasoning")
ax.set_xlabel("Depth"); ax.set_ylabel("Accuracy (%)")
ax.set_title("Accuracy vs Depth — Qwen-2.5-7B on CLUTRR"); ax.legend(frameon=False)

fig.tight_layout()
fig.savefig("figure2_accuracy_reasoning_collapse.pdf", bbox_inches="tight", dpi=400)
plt.close()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# --------------------------------------------------
# PDF/A-SAFE SETTINGS (fonts, vectors, paths)
# --------------------------------------------------
matplotlib.rcParams.update({
    "pdf.fonttype": 42,             # embed TrueType fonts (PDF/A-safe)
    "ps.fonttype": 42,
    "svg.fonttype": 'none',
    "font.family": 'DejaVu Serif',  # always available, open license
    "path.simplify": True,          # reduce path complexity
    "path.simplify_threshold": 0.5, # balance between detail and size
    "agg.path.chunksize": 1000,     # split long paths for PDF/A safety
})

# --------------------------------------------------
# Global styling
# --------------------------------------------------
plt.rcParams.update({
    "font.size": 9,
    "axes.labelsize": 9,
    "axes.titlesize": 9,
    "xtick.labelsize": 8,
    "ytick.labelsize": 8,
    "legend.fontsize": 8,
    "axes.edgecolor": "black",
    "axes.linewidth": 0.8,
    "savefig.dpi": 400,
})

# --------------------------------------------------
# Data definitions
# --------------------------------------------------
depths_gpt5 = np.array([1, 2, 3, 4, 5])
gpt5_direct = [50, 60, 80, 90, 80]
gpt5_reason = [20, 20, 10, 0, 0]
delta_reason = [-25, -40, -70, -90, -80]

depths_llama = np.array([2, 3, 4, 5, 6])
llama_direct = [20, 20, 20, 20, 20]
llama_reason = [30, 20, 20, 20, 20]

depths_qwen = np.array([2, 3, 4, 5, 6])
qwen_direct = [10, 0, 0, 30, 0]
qwen_reason = [10, 0, 20, 0, 0]

# --------------------------------------------------
# Figure layout (2x2 grid)
# --------------------------------------------------
fig, axs = plt.subplots(2, 2, figsize=(6.5, 4.5))
plt.subplots_adjust(wspace=0.35, hspace=0.35)

# --- GPT-5 Accuracy ---
ax = axs[0, 0]
ax.bar(depths_gpt5 - 0.15, gpt5_direct, width=0.3, color="#4c72b0", label="Direct")
ax.bar(depths_gpt5 + 0.15, gpt5_reason, width=0.3, color="#dd8452", label="Reasoning")
ax.set_xlabel("Depth")
ax.set_ylabel("Accuracy (%)")
ax.set_title("Accuracy vs Depth — GPT-5 on ProofWriter")
ax.legend(frameon=False)

# --- GPT-5 ΔReasoning ---
ax = axs[0, 1]
ax.bar(depths_gpt5, delta_reason, color="#4c72b0", edgecolor="black")
ax.set_xlabel("Depth")
ax.set_ylabel("ΔReasoning (pp)")
ax.set_title("ΔReasoning vs Depth — GPT-5 on ProofWriter")

# --- LLaMA-3.1-8B ---
ax = axs[1, 0]
ax.bar(depths_llama - 0.15, llama_direct, width=0.3, color="#4c72b0", label="Direct")
ax.bar(depths_llama + 0.15, llama_reason, width=0.3, color="#dd8452", label="Reasoning")
ax.set_xlabel("Depth")
ax.set_ylabel("Accuracy (%)")
ax.set_title("Accuracy vs Depth — LLaMA-3.1-8B on CLUTRR")
ax.legend(frameon=False)

# --- Qwen-2.5-7B ---
ax = axs[1, 1]
ax.bar(depths_qwen - 0.15, qwen_direct, width=0.3, color="#4c72b0", label="Direct")
ax.bar(depths_qwen + 0.15, qwen_reason, width=0.3, color="#dd8452", label="Reasoning")
ax.set_xlabel("Depth")
ax.set_ylabel("Accuracy (%)")
ax.set_title("Accuracy vs Depth — Qwen-2.5-7B on CLUTRR")
ax.legend(frameon=False)

# --------------------------------------------------
# Save cleanly
# --------------------------------------------------
fig.tight_layout()
fig.savefig("figure2_accuracy_reasoning_collapse.pdf",
            bbox_inches="tight", dpi=400)
plt.close()

# %%
pip install ghostscript
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pymupdf
# Out:
# ...
#    ---------------------------------------- 0.0/18.7 MB ? eta -:--:--
#    ----- ---------------------------------- 2.4/18.7 MB 12.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 5.0/18.7 MB 12.1 MB/s eta 0:00:02
#    --------------- ------------------------ 7.3/18.7 MB 11.9 MB/s eta 0:00:01
#    --------------------- ------------------ 10.0/18.7 MB 11.9 MB/s eta 0:00:01
#    -------------------------- ------------- 12.3/18.7 MB 11.9 MB/s eta 0:00:01
#    ------------------------------- -------- 14.9/18.7 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------ --- 17.3/18.7 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 18.7/18.7 MB 11.6 MB/s  0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import fitz  # PyMuPDF

in_file = "figure2_accuracy_reasoning_collapse.pdf"
out_file = "figure2_accuracy_reasoning_collapse_flat.pdf"

doc = fitz.open(in_file)
doc.save(out_file, deflate=True, garbage=4)
doc.close()

print("✅ Simplified PDF created (PyMuPDF)")
# Out:
# ✅ Simplified PDF created (PyMuPDF)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# --------------------------------------------------
# PDF-friendly settings (version-safe)
# --------------------------------------------------
mpl.rcParams.update({
    "pdf.fonttype": 42,        # embed TrueType (better ToUnicode)
    "ps.fonttype": 42,
    "pdf.compression": 9,      # smaller objects
    "svg.fonttype": "none",
    "font.family": "DejaVu Sans",
    "path.simplify": True,
    "agg.path.chunksize": 1000,
})

plt.rcParams.update({
    "font.size": 9,
    "axes.labelsize": 9,
    "axes.titlesize": 9,
    "xtick.labelsize": 8,
    "ytick.labelsize": 8,
    "legend.fontsize": 8,
    "axes.edgecolor": "black",
    "axes.linewidth": 0.8,
})

# --------------------------------------------------
# Data
# --------------------------------------------------
depths_gpt5 = np.array([1, 2, 3, 4, 5])
gpt5_direct = [50, 60, 80, 90, 80]
gpt5_reason = [20, 20, 10,  0,  0]
delta_reason = [-25, -40, -70, -90, -80]

depths_llama = np.array([2, 3, 4, 5, 6])
llama_direct  = [20, 20, 20, 20, 20]
llama_reason  = [30, 20, 20, 20, 20]

depths_qwen = np.array([2, 3, 4, 5, 6])
qwen_direct = [10,  0,  0, 30,  0]
qwen_reason = [10,  0, 20,  0,  0]

# --------------------------------------------------
# Figure (2x2 grid)
# --------------------------------------------------
fig, axs = plt.subplots(2, 2, figsize=(6.5, 4.5))
plt.subplots_adjust(wspace=0.35, hspace=0.35)

# --- GPT-5 Accuracy ---
ax = axs[0, 0]
ax.bar(depths_gpt5 - 0.15, gpt5_direct,  width=0.3, label="Direct")
ax.bar(depths_gpt5 + 0.15, gpt5_reason,  width=0.3, label="Reasoning")
ax.set_xlabel("Depth")
ax.set_ylabel("Accuracy (%)")
ax.set_title("Accuracy vs Depth - GPT-5 (ProofWriter)")
ax.legend(frameon=False)

# --- GPT-5 Delta Reasoning ---
ax = axs[0, 1]
ax.bar(depths_gpt5, delta_reason, edgecolor="black")
ax.axhline(0, linewidth=0.8, linestyle="--")
ax.set_xlabel("Depth")
ax.set_ylabel("Delta Reasoning (pp)")
ax.set_title("Delta vs Depth - GPT-5 (ProofWriter)")

# --- LLaMA-3.1-8B ---
ax = axs[1, 0]
ax.bar(depths_llama - 0.15, llama_direct, width=0.3, label="Direct")
ax.bar(depths_llama + 0.15, llama_reason, width=0.3, label="Reasoning")
ax.set_xlabel("Depth")
ax.set_ylabel("Accuracy (%)")
ax.set_title("Accuracy vs Depth - LLaMA-3.1-8B (CLUTRR)")
ax.legend(frameon=False)

# --- Qwen-2.5-7B ---
ax = axs[1, 1]
ax.bar(depths_qwen - 0.15, qwen_direct, width=0.3, label="Direct")
ax.bar(depths_qwen + 0.15, qwen_reason, width=0.3, label="Reasoning")
ax.set_xlabel("Depth")
ax.set_ylabel("Accuracy (%)")
ax.set_title("Accuracy vs Depth - Qwen-2.5-7B (CLUTRR)")
ax.legend(frameon=False)

fig.tight_layout()

# --------------------------------------------------
# Save as vector PDF with SHORT metadata (no dpi needed for PDF)
# --------------------------------------------------
meta = {"Title": "Fig2", "Author": "Majeed", "Subject": "", "Keywords": ""}
with PdfPages("figure2_accuracy_reasoning_collapse.pdf", metadata=meta) as pdf:
    pdf.savefig(fig, bbox_inches="tight")

# Optional: PNG fallback (no PDF internals at all)
fig.savefig("figure2_accuracy_reasoning_collapse.png", bbox_inches="tight", dpi=450)

plt.close(fig)

# %%
fig.savefig("figure2_accuracy_reasoning_collapse.png", bbox_inches="tight", dpi=450)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# ==============================
# Single-column sizing for 2-up layout
# ==============================
SINGLE_COL_WIDTH_IN = 3.45   # ~half of a 2-col page (tweak to your \columnwidth)
HEIGHT_IN           = 2.60   # adjust if you want taller/shorter

# ==============================
# PDF-friendly settings + 10 pt text
# ==============================
mpl.rcParams.update({
    "pdf.fonttype": 42, "ps.fonttype": 42, "pdf.compression": 9, "svg.fonttype": "none",
    "font.family": "DejaVu Sans",
    "font.size": 10, "axes.labelsize": 10, "axes.titlesize": 10,
    "xtick.labelsize": 9, "ytick.labelsize": 9, "legend.fontsize": 9,
    "axes.edgecolor": "black", "axes.linewidth": 0.8,
    "path.simplify": True, "agg.path.chunksize": 1000,
})

# ==============================
# Data (as provided)
# ==============================
depths_gpt5 = np.array([1, 2, 3, 4, 5])
gpt5_direct = [50, 60, 80, 90, 80]
gpt5_reason = [20, 20, 10,  0,  0]
delta_reason = [-25, -40, -70, -90, -80]

depths_llama = np.array([2, 3, 4, 5, 6])
llama_direct  = [20, 20, 20, 20, 20]
llama_reason  = [30, 20, 20, 20, 20]

depths_qwen = np.array([2, 3, 4, 5, 6])
qwen_direct = [10,  0,  0, 30,  0]
qwen_reason = [10,  0, 20,  0,  0]

# ==============================
# Helper: consistent pretty axes
# ==============================
def beautify(ax, xlabel, ylabel, title, ylim=None, ystep=None):
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(title, pad=6)
    ax.yaxis.grid(True, linestyle=":", linewidth=0.6, alpha=0.85)
    ax.set_axisbelow(True)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    if ylim is not None:
        ax.set_ylim(ylim)
    if ystep is not None:
        ymin, ymax = ax.get_ylim()
        ax.set_yticks(np.arange(np.ceil(ymin/ystep)*ystep, ymax + 1e-9, ystep))

# ==============================
# (a) GPT-5 Accuracy
# ==============================
fig, ax = plt.subplots(figsize=(SINGLE_COL_WIDTH_IN, HEIGHT_IN))
w = 0.34
ax.bar(depths_gpt5 - w/2, gpt5_direct, width=w, label="Direct", edgecolor="black", linewidth=0.8)
ax.bar(depths_gpt5 + w/2, gpt5_reason, width=w, label="Reasoning", edgecolor="black", linewidth=0.8)
beautify(ax, "Depth", "Accuracy (%)", "Accuracy vs Depth — GPT-5 (ProofWriter)", ylim=(0,100), ystep=20)
ax.legend(frameon=False, ncol=2)
plt.tight_layout()
meta = {"Title": "Fig2a", "Author": "Majeed"}
with PdfPages("fig2a_gpt5_accuracy.pdf", metadata=meta) as pdf:
    pdf.savefig(fig, bbox_inches="tight")
fig.savefig("fig2a_gpt5_accuracy.png", dpi=600, bbox_inches="tight")
plt.close(fig)

# ==============================
# (b) GPT-5 Δ Reasoning
# ==============================
fig, ax = plt.subplots(figsize=(SINGLE_COL_WIDTH_IN, HEIGHT_IN))
ax.bar(depths_gpt5, delta_reason, edgecolor="black", linewidth=0.8)  # keep your colors (none set)
ax.axhline(0, linewidth=0.9, linestyle="--", color="black")
beautify(ax, "Depth", "Δ Reasoning (pp)", "Δ vs Depth — GPT-5 (ProofWriter)", ylim=(-100, 5), ystep=20)
plt.tight_layout()
meta = {"Title": "Fig2b", "Author": "Majeed"}
with PdfPages("fig2b_gpt5_delta.pdf", metadata=meta) as pdf:
    pdf.savefig(fig, bbox_inches="tight")
fig.savefig("fig2b_gpt5_delta.png", dpi=600, bbox_inches="tight")
plt.close(fig)

# ==============================
# (c) LLaMA-3.1-8B Accuracy
# ==============================
fig, ax = plt.subplots(figsize=(SINGLE_COL_WIDTH_IN, HEIGHT_IN))
ax.bar(depths_llama - w/2, llama_direct, width=w, label="Direct", edgecolor="black", linewidth=0.8)
ax.bar(depths_llama + w/2, llama_reason, width=w, label="Reasoning", edgecolor="black", linewidth=0.8)
beautify(ax, "Depth", "Accuracy (%)", "Accuracy vs Depth — LLaMA-3.1-8B (CLUTRR)", ylim=(0,32), ystep=5)
ax.legend(frameon=False, ncol=2)
plt.tight_layout()
meta = {"Title": "Fig2c", "Author": "Majeed"}
with PdfPages("fig2c_llama_accuracy.pdf", metadata=meta) as pdf:
    pdf.savefig(fig, bbox_inches="tight")
fig.savefig("fig2c_llama_accuracy.png", dpi=600, bbox_inches="tight")
plt.close(fig)

# ==============================
# (d) Qwen-2.5-7B Accuracy
# ==============================
fig, ax = plt.subplots(figsize=(SINGLE_COL_WIDTH_IN, HEIGHT_IN))
ax.bar(depths_qwen - w/2, qwen_direct, width=w, label="Direct", edgecolor="black", linewidth=0.8)
ax.bar(depths_qwen + w/2, qwen_reason, width=w, label="Reasoning", edgecolor="black", linewidth=0.8)
beautify(ax, "Depth", "Accuracy (%)", "Accuracy vs Depth — Qwen-2.5-7B (CLUTRR)", ylim=(0,32), ystep=5)
ax.legend(frameon=False, ncol=2)
plt.tight_layout()
meta = {"Title": "Fig2d", "Author": "Majeed"}
with PdfPages("fig2d_qwen_accuracy.pdf", metadata=meta) as pdf:
    pdf.savefig(fig, bbox_inches="tight")
fig.savefig("fig2d_qwen_accuracy.png", dpi=600, bbox_inches="tight")
plt.close(fig)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# ------------------------------
# Single-column sizing (2-up)
# ------------------------------
SINGLE_COL_WIDTH_IN = 3.45
HEIGHT_IN           = 2.60

# ------------------------------
# PDF-friendly settings + 10 pt
# ------------------------------
mpl.rcParams.update({
    "pdf.fonttype": 42, "ps.fonttype": 42, "pdf.compression": 9, "svg.fonttype": "none",
    "font.family": "DejaVu Sans",
    "font.size": 10, "axes.labelsize": 10, "axes.titlesize": 10,
    "xtick.labelsize": 9, "ytick.labelsize": 9, "legend.fontsize": 9,
    "axes.edgecolor": "black", "axes.linewidth": 0.8,
    "path.simplify": True, "agg.path.chunksize": 1000,
})

# ------------------------------
# Data
# ------------------------------
depths_gpt5 = np.array([1, 2, 3, 4, 5])
gpt5_direct = [50, 60, 80, 90, 80]
gpt5_reason = [20, 20, 10,  0,  0]
delta_reason = [-25, -40, -70, -90, -80]

depths_llama = np.array([2, 3, 4, 5, 6])
llama_direct  = [20, 20, 20, 20, 20]
llama_reason  = [30, 20, 20, 20, 20]

depths_qwen = np.array([2, 3, 4, 5, 6])
qwen_direct = [10,  0,  0, 30,  0]
qwen_reason = [10,  0, 20,  0,  0]

# ------------------------------
# Helpers
# ------------------------------
def beautify(ax, xlabel, ylabel, title, ylim=None, ystep=None):
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(title, pad=10)  # slightly larger pad to clear legend area
    ax.yaxis.grid(True, linestyle=":", linewidth=0.6, alpha=0.85)
    ax.set_axisbelow(True)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    if ylim is not None:
        ax.set_ylim(ylim)
    if ystep is not None:
        ymin, ymax = ax.get_ylim()
        ax.set_yticks(np.arange(np.ceil(ymin/ystep)*ystep, ymax + 1e-9, ystep))

def place_legend_above(ax, ncol=2):
    ax.margins(y=0.02)
    ax.legend(
        loc="upper center",
        bbox_to_anchor=(0.5, 1.24),   # higher so it never touches the title
        ncol=ncol,
        frameon=True,
        edgecolor="black",
        handlelength=1.4,
        borderaxespad=0.2
    )

# ------------------------------
# (a) GPT-5 Accuracy
# ------------------------------
fig, ax = plt.subplots(figsize=(SINGLE_COL_WIDTH_IN, HEIGHT_IN))
w = 0.34
ax.bar(depths_gpt5 - w/2, gpt5_direct, width=w, label="Direct",
       edgecolor="black", linewidth=0.8)
ax.bar(depths_gpt5 + w/2, gpt5_reason, width=w, label="Reasoning",
       edgecolor="black", linewidth=0.8)
beautify(ax, "Depth", "Accuracy (%)", "Accuracy vs Depth — GPT-5 (ProofWriter)", ylim=(0, 100), ystep=20)
place_legend_above(ax)
plt.tight_layout(rect=[0, 0, 1, 0.82])  # reserve extra top space for legend
with PdfPages("fig2a_gpt5_accuracy.pdf", metadata={"Title": "Fig2a", "Author": "Majeed"}) as pdf:
    pdf.savefig(fig, bbox_inches="tight")
fig.savefig("fig2a_gpt5_accuracy.png", dpi=600, bbox_inches="tight")
plt.close(fig)

# ------------------------------
# (b) GPT-5 Δ Reasoning  (no legend)
# ------------------------------
fig, ax = plt.subplots(figsize=(SINGLE_COL_WIDTH_IN, HEIGHT_IN))
ax.bar(depths_gpt5, delta_reason, edgecolor="black", linewidth=0.8)
ax.axhline(0, linewidth=0.9, linestyle="--", color="black")
beautify(ax, "Depth", "Δ Reasoning (pp)", "Δ vs Depth — GPT-5 (ProofWriter)", ylim=(-100, 5), ystep=20)
plt.tight_layout()
with PdfPages("fig2b_gpt5_delta.pdf", metadata={"Title": "Fig2b", "Author": "Majeed"}) as pdf:
    pdf.savefig(fig, bbox_inches="tight")
fig.savefig("fig2b_gpt5_delta.png", dpi=600, bbox_inches="tight")
plt.close(fig)

# ------------------------------
# (c) LLaMA-3.1-8B Accuracy
# ------------------------------
fig, ax = plt.subplots(figsize=(SINGLE_COL_WIDTH_IN, HEIGHT_IN))
ax.bar(depths_llama - w/2, llama_direct, width=w, label="Direct",
       edgecolor="black", linewidth=0.8)
ax.bar(depths_llama + w/2, llama_reason, width=w, label="Reasoning",
       edgecolor="black", linewidth=0.8)
beautify(ax, "Depth", "Accuracy (%)", "Accuracy vs Depth — LLaMA-3.1-8B (CLUTRR)", ylim=(0, 32), ystep=5)
place_legend_above(ax)
plt.tight_layout(rect=[0, 0, 1, 0.82])
with PdfPages("fig2c_llama_accuracy.pdf", metadata={"Title": "Fig2c", "Author": "Majeed"}) as pdf:
    pdf.savefig(fig, bbox_inches="tight")
fig.savefig("fig2c_llama_accuracy.png", dpi=600, bbox_inches="tight")
plt.close(fig)

# ------------------------------
# (d) Qwen-2.5-7B Accuracy
# ------------------------------
fig, ax = plt.subplots(figsize=(SINGLE_COL_WIDTH_IN, HEIGHT_IN))
ax.bar(depths_qwen - w/2, qwen_direct, width=w, label="Direct",
       edgecolor="black", linewidth=0.8)
ax.bar(depths_qwen + w/2, qwen_reason, width=w, label="Reasoning",
       edgecolor="black", linewidth=0.8)
beautify(ax, "Depth", "Accuracy (%)", "Accuracy vs Depth — Qwen-2.5-7B (CLUTRR)", ylim=(0, 32), ystep=5)
place_legend_above(ax)
plt.tight_layout(rect=[0, 0, 1, 0.82])
with PdfPages("fig2d_qwen_accuracy.pdf", metadata={"Title": "Fig2d", "Author": "Majeed"}) as pdf:
    pdf.savefig(fig, bbox_inches="tight")
fig.savefig("fig2d_qwen_accuracy.png", dpi=600, bbox_inches="tight")
plt.close(fig)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib.gridspec import GridSpec

# ------------------------------
# Sizing for two-up layout
# ------------------------------
SINGLE_COL_WIDTH_IN = 3.45
HEIGHT_IN = 2.60

# ------------------------------
# PDF-friendly + 10 pt text
# ------------------------------
mpl.rcParams.update({
    "pdf.fonttype": 42, "ps.fonttype": 42, "pdf.compression": 9, "svg.fonttype": "none",
    "font.family": "DejaVu Sans",
    "font.size": 10, "axes.labelsize": 10, "axes.titlesize": 10,
    "xtick.labelsize": 9, "ytick.labelsize": 9, "legend.fontsize": 9,
    "axes.edgecolor": "black", "axes.linewidth": 0.8,
    "path.simplify": True, "agg.path.chunksize": 1000,
})

# ------------------------------
# Data
# ------------------------------
depths_gpt5 = np.array([1, 2, 3, 4, 5])
gpt5_direct = [50, 60, 80, 90, 80]
gpt5_reason = [20, 20, 10,  0,  0]
delta_reason = [-25, -40, -70, -90, -80]

depths_llama = np.array([2, 3, 4, 5, 6])
llama_direct  = [20, 20, 20, 20, 20]
llama_reason  = [30, 20, 20, 20, 20]

depths_qwen = np.array([2, 3, 4, 5, 6])
qwen_direct = [10,  0,  0, 30,  0]
qwen_reason = [10,  0, 20,  0,  0]

def prettify(ax, xlabel, ylabel, title, ylim=None, ystep=None):
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(title, pad=8)
    ax.yaxis.grid(True, linestyle=":", linewidth=0.6, alpha=0.85)
    ax.set_axisbelow(True)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    if ylim is not None:
        ax.set_ylim(ylim)
    if ystep is not None:
        ymin, ymax = ax.get_ylim()
        ax.set_yticks(np.arange(np.ceil(ymin/ystep)*ystep, ymax + 1e-9, ystep))

def save(fig, pdf_name, png_name, meta_title):
    with PdfPages(pdf_name, metadata={"Title": meta_title, "Author": "Majeed"}) as pdf:
        pdf.savefig(fig, bbox_inches="tight")
    fig.savefig(png_name, dpi=600, bbox_inches="tight")
    plt.close(fig)

def bar_with_legend_top(x, y1, y2, title, ylim, ystep, pdf_name, png_name):
    # Legend gets its own axis row (no overlap possible)
    fig = plt.figure(figsize=(SINGLE_COL_WIDTH_IN, HEIGHT_IN))
    gs = GridSpec(nrows=2, ncols=1, height_ratios=[0.28, 1.0], hspace=0.05, figure=fig)

    ax_leg = fig.add_subplot(gs[0, 0])
    ax_leg.axis("off")  # legend-only band

    ax = fig.add_subplot(gs[1, 0])
    w = 0.34
    bars1 = ax.bar(x - w/2, y1, width=w, label="Direct", edgecolor="black", linewidth=0.8)
    bars2 = ax.bar(x + w/2, y2, width=w, label="Reasoning", edgecolor="black", linewidth=0.8)

    # Put legend in the legend band (never overlaps the plot)
    handles = [bars1, bars2]
    ax_leg.legend(handles=[h[0] for h in handles], labels=["Direct", "Reasoning"],
                  loc="center", ncol=2, frameon=True, edgecolor="black", handlelength=1.4)

    prettify(ax, "Depth", "Accuracy (%)", title, ylim=ylim, ystep=ystep)
    save(fig, pdf_name, png_name, meta_title=pdf_name.split(".")[0])

def bar_no_legend(x, y, title, ylim, ystep, pdf_name, png_name):
    fig = plt.figure(figsize=(SINGLE_COL_WIDTH_IN, HEIGHT_IN))
    gs = GridSpec(nrows=1, ncols=1, figure=fig)
    ax = fig.add_subplot(gs[0, 0])
    ax.bar(x, y, edgecolor="black", linewidth=0.8)
    ax.axhline(0, linewidth=0.9, linestyle="--", color="black")
    prettify(ax, "Depth", "Δ Reasoning (pp)", title, ylim=ylim, ystep=ystep)
    save(fig, pdf_name, png_name, meta_title=pdf_name.split(".")[0])

# ---- (a) GPT-5 Accuracy
bar_with_legend_top(
    depths_gpt5, gpt5_direct, gpt5_reason,
    "Accuracy vs Depth — GPT-5 (ProofWriter)",
    ylim=(0,100), ystep=20,
    pdf_name="fig2a_gpt5_accuracy.pdf", png_name="fig2a_gpt5_accuracy.png"
)

# ---- (b) GPT-5 Δ Reasoning (no legend)
bar_no_legend(
    depths_gpt5, delta_reason,
    "Δ vs Depth — GPT-5 (ProofWriter)",
    ylim=(-100,5), ystep=20,
    pdf_name="fig2b_gpt5_delta.pdf", png_name="fig2b_gpt5_delta.png"
)

# ---- (c) LLaMA-3.1-8B Accuracy
bar_with_legend_top(
    depths_llama, llama_direct, llama_reason,
    "Accuracy vs Depth — LLaMA-3.1-8B (CLUTRR)",
    ylim=(0,32), ystep=5,
    pdf_name="fig2c_llama_accuracy.pdf", png_name="fig2c_llama_accuracy.png"
)

# ---- (d) Qwen-2.5-7B Accuracy
bar_with_legend_top(
    depths_qwen, qwen_direct, qwen_reason,
    "Accuracy vs Depth — Qwen-2.5-7B (CLUTRR)",
    ylim=(0,32), ystep=5,
    pdf_name="fig2d_qwen_accuracy.pdf", png_name="fig2d_qwen_accuracy.png"
)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib.gridspec import GridSpec

# ------------------------------
# Sizing for two-up layout
# ------------------------------
SINGLE_COL_WIDTH_IN = 3.45
HEIGHT_IN = 2.60

# ------------------------------
# PDF-friendly + 10 pt text
# ------------------------------
mpl.rcParams.update({
    "pdf.fonttype": 42, "ps.fonttype": 42, "pdf.compression": 9, "svg.fonttype": "none",
    "font.family": "DejaVu Sans",
    "font.size": 10, "axes.labelsize": 10, "axes.titlesize": 10,
    "xtick.labelsize": 9, "ytick.labelsize": 9, "legend.fontsize": 9,
    "axes.edgecolor": "black", "axes.linewidth": 0.8,
    "path.simplify": True, "agg.path.chunksize": 1000,
})

# ------------------------------
# Data
# ------------------------------
depths_gpt5 = np.array([1, 2, 3, 4, 5])
gpt5_direct = [50, 60, 80, 90, 80]
gpt5_reason = [20, 20, 10,  0,  0]
delta_reason = [-25, -40, -70, -90, -80]

depths_llama = np.array([2, 3, 4, 5, 6])
llama_direct  = [20, 20, 20, 20, 20]
llama_reason  = [30, 20, 20, 20, 20]

depths_qwen = np.array([2, 3, 4, 5, 6])
qwen_direct = [10,  0,  0, 30,  0]
qwen_reason = [10,  0, 20,  0,  0]

def prettify(ax, xlabel, ylabel, title, ylim=None, ystep=None):
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(title, pad=8)
    ax.yaxis.grid(True, linestyle=":", linewidth=0.6, alpha=0.85)
    ax.set_axisbelow(True)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    if ylim is not None:
        ax.set_ylim(ylim)
    if ystep is not None:
        ymin, ymax = ax.get_ylim()
        ax.set_yticks(np.arange(np.ceil(ymin/ystep)*ystep, ymax + 1e-9, ystep))

def save(fig, pdf_name, png_name, meta_title):
    with PdfPages(pdf_name, metadata={"Title": meta_title, "Author": "Majeed"}) as pdf:
        pdf.savefig(fig, bbox_inches="tight")
    fig.savefig(png_name, dpi=600, bbox_inches="tight")
    plt.close(fig)

def bar_with_legend_bottom(x, y1, y2, title, ylim, ystep, pdf_name, png_name):
    fig, ax = plt.subplots(figsize=(SINGLE_COL_WIDTH_IN, HEIGHT_IN))

    w = 0.34
    b1 = ax.bar(x - w/2, y1, width=w, label="Direct",
                edgecolor="black", linewidth=0.8)
    b2 = ax.bar(x + w/2, y2, width=w, label="Reasoning",
                edgecolor="black", linewidth=0.8)

    # normal, safe x-label placement (inside axes)
    ax.set_xlabel("Depth", labelpad=6)
    ax.set_ylabel("Accuracy (%)")
    ax.set_title(title, pad=8)
    ax.yaxis.grid(True, linestyle=":", linewidth=0.6, alpha=0.85)
    ax.set_axisbelow(True)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    if ylim is not None:
        ax.set_ylim(ylim)
    if ystep is not None:
        ymin, ymax = ax.get_ylim()
        ax.set_yticks(np.arange(np.ceil(ymin/ystep)*ystep, ymax + 1e-9, ystep))

    # Reserve a deeper bottom margin for the outside legend
    # (no tight_layout here—let subplots_adjust take control)
    fig.subplots_adjust(left=0.12, right=0.98, top=0.86, bottom=0.34)

    # Legend OUTSIDE in figure coordinates, lower than before
    fig.legend(
        [b1, b2], ["Direct", "Reasoning"],
        loc="lower center",
        bbox_to_anchor=(0.5, 0.04),   # was ~0.06–0.08; push further down
        ncol=2, frameon=True, edgecolor="black", handlelength=1.4
    )

    with PdfPages(pdf_name, metadata={"Title": pdf_name.split(".")[0], "Author": "Majeed"}) as pdf:
        pdf.savefig(fig, bbox_inches="tight")
    fig.savefig(png_name, dpi=600, bbox_inches="tight")
    plt.close(fig)




def bar_no_legend(x, y, title, ylim, ystep, pdf_name, png_name):
    fig = plt.figure(figsize=(SINGLE_COL_WIDTH_IN, HEIGHT_IN))
    ax = fig.add_axes([0.12, 0.18, 0.84, 0.74])  # stable manual margins
    ax.bar(x, y, edgecolor="black", linewidth=0.8)
    ax.axhline(0, linewidth=0.9, linestyle="--", color="black")
    prettify(ax, "Depth", "Δ Reasoning (pp)", title, ylim=ylim, ystep=ystep)
    save(fig, pdf_name, png_name, meta_title=pdf_name.split(".")[0])

# ---- (a) GPT-5 Accuracy
bar_with_legend_bottom(
    depths_gpt5, gpt5_direct, gpt5_reason,
    "Accuracy vs Depth — GPT-5 (ProofWriter)",
    ylim=(0,100), ystep=20,
    pdf_name="fig2a_gpt5_accuracy.pdf", png_name="fig2a_gpt5_accuracy.png"
)

# ---- (b) GPT-5 Δ Reasoning (no legend)
bar_no_legend(
    depths_gpt5, delta_reason,
    "Δ vs Depth — GPT-5 (ProofWriter)",
    ylim=(-100,5), ystep=20,
    pdf_name="fig2b_gpt5_delta.pdf", png_name="fig2b_gpt5_delta.png"
)

# ---- (c) LLaMA-3.1-8B Accuracy
bar_with_legend_bottom(
    depths_llama, llama_direct, llama_reason,
    "Accuracy vs Depth — LLaMA-3.1-8B (CLUTRR)",
    ylim=(0,32), ystep=5,
    pdf_name="fig2c_llama_accuracy.pdf", png_name="fig2c_llama_accuracy.png"
)

# ---- (d) Qwen-2.5-7B Accuracy
bar_with_legend_bottom(
    depths_qwen, qwen_direct, qwen_reason,
    "Accuracy vs Depth — Qwen-2.5-7B (CLUTRR)",
    ylim=(0,32), ystep=5,
    pdf_name="fig2d_qwen_accuracy.pdf", png_name="fig2d_qwen_accuracy.png"
)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# ------------------------------
# Sizing for two-up layout
# ------------------------------
SINGLE_COL_WIDTH_IN = 3.45        # keep width (single column)
HEIGHT_IN = 3.1                   # <-- make it taller (was 2.60)

# You can push HEIGHT_IN to 3.2 or even 3.3 if you want more height

# ------------------------------
# PNG-friendly + 10 pt text
# ------------------------------
mpl.rcParams.update({
    "pdf.fonttype": 42, "ps.fonttype": 42, "pdf.compression": 9, "svg.fonttype": "none",
    "font.family": "DejaVu Sans",
    "font.size": 10, "axes.labelsize": 10, "axes.titlesize": 10,
    "xtick.labelsize": 9, "ytick.labelsize": 9, "legend.fontsize": 9,
    "axes.edgecolor": "black", "axes.linewidth": 0.8,
    "path.simplify": True, "agg.path.chunksize": 1000,
})

# ------------------------------
# Data
# ------------------------------
depths_gpt5 = np.array([1, 2, 3, 4, 5])
gpt5_direct = [50, 60, 80, 90, 80]
gpt5_reason = [20, 20, 10,  0,  0]
delta_reason = [-25, -40, -70, -90, -80]

depths_llama = np.array([2, 3, 4, 5, 6])
llama_direct  = [20, 20, 20, 20, 20]
llama_reason  = [30, 20, 20, 20, 20]

depths_qwen = np.array([2, 3, 4, 5, 6])
qwen_direct = [10,  0,  0, 30,  0]
qwen_reason = [10,  0, 20,  0,  0]


def prettify(ax, xlabel, ylabel, title, ylim=None, ystep=None):
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(title, pad=8)
    ax.yaxis.grid(True, linestyle=":", linewidth=0.6, alpha=0.85)
    ax.set_axisbelow(True)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    if ylim is not None:
        ax.set_ylim(ylim)
    if ystep is not None:
        ymin, ymax = ax.get_ylim()
        ax.set_yticks(np.arange(np.ceil(ymin/ystep)*ystep, ymax + 1e-9, ystep))


def save(fig, pdf_name, png_name, meta_title):
    # PDF (optional, you can ignore if platform doesn’t use it)
    with PdfPages(pdf_name, metadata={"Title": meta_title, "Author": "Majeed"}) as pdf:
        pdf.savefig(fig, bbox_inches="tight")

    # HIGH-RES PNG for AAAI upload
    fig.savefig(
        png_name,
        dpi=600,          # <-- this is what makes it high resolution
        bbox_inches="tight"
    )
    plt.close(fig)


def bar_with_legend_bottom(x, y1, y2, title, ylim, ystep, pdf_name, png_name):
    fig, ax = plt.subplots(figsize=(SINGLE_COL_WIDTH_IN, HEIGHT_IN))

    w = 0.34
    b1 = ax.bar(x - w/2, y1, width=w, label="Direct",
                edgecolor="black", linewidth=0.8)
    b2 = ax.bar(x + w/2, y2, width=w, label="Reasoning",
                edgecolor="black", linewidth=0.8)

    ax.set_xlabel("Depth", labelpad=6)
    ax.set_ylabel("Accuracy (%)")
    ax.set_title(title, pad=8)
    ax.yaxis.grid(True, linestyle=":", linewidth=0.6, alpha=0.85)
    ax.set_axisbelow(True)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)

    if ylim is not None:
        ax.set_ylim(ylim)
    if ystep is not None:
        ymin, ymax = ax.get_ylim()
        ax.set_yticks(np.arange(np.ceil(ymin/ystep)*ystep, ymax + 1e-9, ystep))

    # More room at the bottom for the legend
    # (this shrinks the axes a bit vertically)
    fig.subplots_adjust(left=0.14, right=0.98, top=0.86, bottom=0.30)

    # Legend *below* the x-axis, not overlapping the "Depth" label
    ax.legend(
        loc="upper center",
        bbox_to_anchor=(0.5, -0.22),   # negative y -> below the axis
        ncol=2,
        frameon=True,
        edgecolor="black",
        handlelength=1.4
    )

    save(fig, pdf_name, png_name, meta_title=pdf_name.split(".")[0])



def bar_no_legend(x, y, title, ylim, ystep, pdf_name, png_name):
    # taller figure here too
    fig = plt.figure(figsize=(SINGLE_COL_WIDTH_IN, HEIGHT_IN))
    ax = fig.add_axes([0.12, 0.18, 0.84, 0.74])
    ax.bar(x, y, edgecolor="black", linewidth=0.8)
    ax.axhline(0, linewidth=0.9, linestyle="--", color="black")
    prettify(ax, "Depth", "Δ Reasoning (pp)", title, ylim=ylim, ystep=ystep)
    save(fig, pdf_name, png_name, meta_title=pdf_name.split(".")[0])


# ---- (a) GPT-5 Accuracy
bar_with_legend_bottom(
    depths_gpt5, gpt5_direct, gpt5_reason,
    "Accuracy vs Depth — GPT-5 (ProofWriter)",
    ylim=(0,100), ystep=20,
    pdf_name="fig2a_gpt5_accuracy.pdf", png_name="fig2a_gpt5_accuracy.png"
)

# ---- (b) GPT-5 Δ Reasoning (no legend)
bar_no_legend(
    depths_gpt5, delta_reason,
    "Δ vs Depth — GPT-5 (ProofWriter)",
    ylim=(-100,5), ystep=20,
    pdf_name="fig2b_gpt5_delta.pdf", png_name="fig2b_gpt5_delta.png"
)

# ---- (c) LLaMA-3.1-8B Accuracy
bar_with_legend_bottom(
    depths_llama, llama_direct, llama_reason,
    "Accuracy vs Depth — LLaMA-3.1-8B (CLUTRR)",
    ylim=(0,32), ystep=5,
    pdf_name="fig2c_llama_accuracy.pdf", png_name="fig2c_llama_accuracy.png"
)

# ---- (d) Qwen-2.5-7B Accuracy
bar_with_legend_bottom(
    depths_qwen, qwen_direct, qwen_reason,
    "Accuracy vs Depth — Qwen-2.5-7B (CLUTRR)",
    ylim=(0,32), ystep=5,
    pdf_name="fig2d_qwen_accuracy.pdf", png_name="fig2d_qwen_accuracy.png"
)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# ------------------------------
# Sizing for two-up layout
# ------------------------------
SINGLE_COL_WIDTH_IN = 3.45
HEIGHT_IN = 2.8        # a bit shorter than 3.1; keeps aspect reasonable

# ------------------------------
# BIGGER FONTS so they stay readable after LaTeX shrink
# ------------------------------
mpl.rcParams.update({
    "pdf.fonttype": 42, "ps.fonttype": 42, "pdf.compression": 9, "svg.fonttype": "none",
    "font.family": "DejaVu Sans",

    # was 10 / 9 everywhere – now larger
    "font.size": 16,          # base size
    "axes.labelsize": 16,
    "axes.titlesize": 16,
    "xtick.labelsize": 14,
    "ytick.labelsize": 14,
    "legend.fontsize": 14,

    "axes.edgecolor": "black", "axes.linewidth": 0.8,
    "path.simplify": True, "agg.path.chunksize": 1000,
})

# ------------------------------
# Data
# ------------------------------
depths_gpt5 = np.array([1, 2, 3, 4, 5])
gpt5_direct = [50, 60, 80, 90, 80]
gpt5_reason = [20, 20, 10,  0,  0]
delta_reason = [-25, -40, -70, -90, -80]

depths_llama = np.array([2, 3, 4, 5, 6])
llama_direct  = [20, 20, 20, 20, 20]
llama_reason  = [30, 20, 20, 20, 20]

depths_qwen = np.array([2, 3, 4, 5, 6])
qwen_direct = [10,  0,  0, 30,  0]
qwen_reason = [10,  0, 20,  0,  0]


def prettify(ax, xlabel, ylabel, title, ylim=None, ystep=None):
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(title, pad=8)
    ax.yaxis.grid(True, linestyle=":", linewidth=0.6, alpha=0.85)
    ax.set_axisbelow(True)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    if ylim is not None:
        ax.set_ylim(ylim)
    if ystep is not None:
        ymin, ymax = ax.get_ylim()
        ax.set_yticks(np.arange(np.ceil(ymin/ystep)*ystep, ymax + 1e-9, ystep))


def save(fig, pdf_name, png_name, meta_title):
    with PdfPages(pdf_name, metadata={"Title": meta_title, "Author": "Majeed"}) as pdf:
        pdf.savefig(fig, bbox_inches="tight")

    fig.savefig(
        png_name,
        dpi=600,              # keep high resolution
        bbox_inches="tight"
    )
    plt.close(fig)


def bar_with_legend_bottom(x, y1, y2, title, ylim, ystep, pdf_name, png_name):
    fig, ax = plt.subplots(figsize=(SINGLE_COL_WIDTH_IN, HEIGHT_IN))

    w = 0.34
    b1 = ax.bar(x - w/2, y1, width=w, label="Direct",
                edgecolor="black", linewidth=0.8)
    b2 = ax.bar(x + w/2, y2, width=w, label="Reasoning",
                edgecolor="black", linewidth=0.8)

    ax.set_xlabel("Depth", labelpad=6)
    ax.set_ylabel("Accuracy (%)")
    ax.set_title(title, pad=8)
    ax.yaxis.grid(True, linestyle=":", linewidth=0.6, alpha=0.85)
    ax.set_axisbelow(True)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)

    if ylim is not None:
        ax.set_ylim(ylim)
    if ystep is not None:
        ymin, ymax = ax.get_ylim()
        ax.set_yticks(np.arange(np.ceil(ymin/ystep)*ystep, ymax + 1e-9, ystep))

    # Give more space at the bottom for the legend
    fig.subplots_adjust(left=0.14, right=0.98, top=0.86, bottom=0.32)

    # Legend clearly below the x-label (no overlap)
    fig.legend(
        [b1, b2], ["Direct", "Reasoning"],
        loc="lower center",
        bbox_to_anchor=(0.5, 0.02),   # lower in figure coords
        ncol=2,
        frameon=True,
        edgecolor="black",
        handlelength=1.4
    )

    save(fig, pdf_name, png_name, meta_title=pdf_name.split(".")[0])


def bar_no_legend(x, y, title, ylim, ystep, pdf_name, png_name):
    fig = plt.figure(figsize=(SINGLE_COL_WIDTH_IN, HEIGHT_IN))
    ax = fig.add_axes([0.12, 0.18, 0.84, 0.74])
    ax.bar(x, y, edgecolor="black", linewidth=0.8)
    ax.axhline(0, linewidth=0.9, linestyle="--", color="black")
    prettify(ax, "Depth", "Δ Reasoning (pp)", title, ylim=ylim, ystep=ystep)
    save(fig, pdf_name, png_name, meta_title=pdf_name.split(".")[0])


# ---- (a) GPT-5 Accuracy
bar_with_legend_bottom(
    depths_gpt5, gpt5_direct, gpt5_reason,
    "Accuracy vs Depth — GPT-5 (ProofWriter)",
    ylim=(0,100), ystep=20,
    pdf_name="fig2a_gpt5_accuracy.pdf", png_name="fig2a_gpt5_accuracy.png"
)

# ---- (b) GPT-5 Δ Reasoning (no legend)
bar_no_legend(
    depths_gpt5, delta_reason,
    "Δ vs Depth — GPT-5 (ProofWriter)",
    ylim=(-100,5), ystep=20,
    pdf_name="fig2b_gpt5_delta.pdf", png_name="fig2b_gpt5_delta.png"
)

# ---- (c) LLaMA-3.1-8B Accuracy
bar_with_legend_bottom(
    depths_llama, llama_direct, llama_reason,
    "Accuracy vs Depth — LLaMA-3.1-8B (CLUTRR)",
    ylim=(0,32), ystep=5,
    pdf_name="fig2c_llama_accuracy.pdf", png_name="fig2c_llama_accuracy.png"
)

# ---- (d) Qwen-2.5-7B Accuracy
bar_with_legend_bottom(
    depths_qwen, qwen_direct, qwen_reason,
    "Accuracy vs Depth — Qwen-2.5-7B (CLUTRR)",
    ylim=(0,32), ystep=5,
    pdf_name="fig2d_qwen_accuracy.pdf", png_name="fig2d_qwen_accuracy.png"
)
